# %% [markdown]
# <a href="https://colab.research.google.com/github/zayedupal/Safety-helmet-detection-YOLO/blob/main/Paper_Helmet_Detection_YoloV8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# install lib

# %%
# !pip install ultralytics --q
# !pip install roboflow --q
# !pip install datasets --q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 17.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# imports

# %%
import torch
from PIL import Image
import cv2
from tqdm import tqdm
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
from roboflow import Roboflow

# %% [markdown]
# # Load dataset from Roboflow and train

# %% [markdown]
# load dataset

# %%
rf = Roboflow(api_key="INSERT-YOUR-API-KEY-HERE")
project = rf.workspace("zayed-uddin-chowdhury-ghymx").project("safety-helmet-wearing-dataset")
dataset = project.version(3).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.208, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Safety-Helmet-Wearing-Dataset-3 in yolov8:: 100%|██████████| 15096/15096 [00:02<00:00, 5999.63it/s]

# %% [markdown]
# Open the data.yaml and change the train path from Counting-Bags-for-Labours-5/train/images/ to ../train images, do the same for val path.

# %%
model = YOLO('yolov8m.pt')

# %%
model.train(task='detect', data='/content/Safety-Helmet-Wearing-Dataset-3/data.yaml', epochs=100, imgsz=640, batch=32)
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model = YOLO('/content/yolov8_best.pt')

# %%
model.val(conf=0.7)
# Out:
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/Safety-Helmet-Wearing-Dataset-3/valid/labels.cache... 1505 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1505/1505 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 95/95 [00:50<00:00,  1.89it/s]
#                    all       1505      24509      0.971      0.817      0.898       0.63
#                    hat       1505       1838      0.967       0.85      0.914      0.748
#                 person       1505      22671      0.975      0.783      0.882      0.512
# Speed: 0.6ms preprocess, 20.6ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs/detect/val2
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# box: ultralytics.utils.metrics.Metric object
# ...

# %%
from os import listdir
from os.path import isfile, join

img_dir = '/content/Safety-Helmet-Wearing-Dataset-3/test/images'
files = [f for f in listdir(img_dir) if isfile(join(img_dir, f))]
model_path = '/content/yolov8_best.pt'

model = YOLO(model_path)

speeds = []
for file in files:
  img_path = f'{img_dir}/{file}'

  frame = cv2.imread(img_path)

  results = model.predict(frame, conf=0.60, iou=0.6)
  speeds.append(sum(results[0].speed.values()))

print(f'speeds: {speeds}')
print(f'fps: {sum(speeds)/len(speeds)}')

# %%
from os import listdir
from os.path import isfile, join
from ultralytics.utils.plotting import Annotator

img_dir = '/content/Safety-Helmet-Wearing-Dataset-3/test/images'
files = [f for f in listdir(img_dir) if isfile(join(img_dir, f))]
model_path = '/content/yolov8_best.pt'
output_dir = '/content/test_results'

model = YOLO(model_path)

for file in files:
  img_path = f'{img_dir}/{file}'

  frame = cv2.imread(img_path)

  results = model.predict(frame, conf=0.7, iou=0.6)

  for r in results:

        annotator = Annotator(frame)

        boxes = r.boxes
        for box in boxes:

            b = box.xyxy[0]  # get box coordinates in (top, left, bottom, right) format
            c = box.cls
            annotator.box_label(b, model.names[int(c)])

  frame = annotator.result()

  cv2.imwrite(f"{output_dir}/{file}", frame)
# Out:
# 0: 640x640 2 hats, 37.0ms
# Speed: 2.1ms preprocess, 37.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 hats, 37.1ms
# Speed: 2.3ms preprocess, 37.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 27 persons, 29.9ms
# Speed: 2.0ms preprocess, 29.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 persons, 26.3ms
# Speed: 2.6ms preprocess, 26.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 persons, 26.3ms
# Speed: 3.3ms preprocess, 26.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 hat, 26.2ms
# Speed: 2.8ms preprocess, 26.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 persons, 26.3ms
# Speed: 3.1ms preprocess, 26.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 persons, 26.6ms
# ...

# %%
# !nvidia-smi

# %%
ultralytics.checks()
